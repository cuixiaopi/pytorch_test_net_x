# %%
import torch
a=torch.rand(3,3,4,5)
print(a)
a1=a.index_select(0,torch.tensor([1,2])) #对3张照片的后两张进行操作
print(a1)
print(a1.shape)
# Out:
# tensor([[[[0.9830, 0.3615, 0.3720, 0.4532, 0.2566],
#           [0.3365, 0.6990, 0.3042, 0.5889, 0.5158],
#           [0.6140, 0.3368, 0.3294, 0.0432, 0.8223],
#           [0.3488, 0.6140, 0.4692, 0.8572, 0.0397]],
#
#          [[0.3349, 0.2773, 0.3943, 0.9946, 0.9741],
#           [0.7739, 0.5524, 0.8783, 0.1720, 0.3443],
#           [0.6257, 0.0156, 0.6140, 0.3745, 0.2307],
#           [0.2603, 0.4297, 0.1153, 0.3469, 0.4841]],
#
#          [[0.9854, 0.5584, 0.5761, 0.3142, 0.2282],
#           [0.0296, 0.1624, 0.1559, 0.8208, 0.6820],
#           [0.8758, 0.0745, 0.9211, 0.1327, 0.2258],
#           [0.2812, 0.4056, 0.5251, 0.2320, 0.8205]]],
#
#
#         [[[0.1477, 0.4478, 0.3124, 0.1126, 0.5720],
#           [0.7289, 0.1711, 0.1969, 0.3191, 0.8261],
#           [0.2790, 0.5816, 0.0922, 0.7201, 0.3478],
#           [0.9068, 0.3046, 0.1437, 0.5120, 0.8655]],
#
#          [[0.1001, 0.9903, 0.3409, 0.5940, 0.5004],
#           [0.4530, 0.5146, 0.9617, 0.5641, 0.0232],
# ...
